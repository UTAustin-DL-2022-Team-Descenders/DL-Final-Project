# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %cd ../code
# Out:
# /home/jrojas/work/utaustin/deep-learning/DL-Final-Project/code

# %% [markdown]
# Play AI vs each other

# %%
VIDEO_FILE='../data/video.gif'
DATA_FILE='../data/state.pkl'
# %run -m tournament.runner AI AI --record_video $VIDEO_FILE --record_state $DATA_FILE
# Out:
# Match results [0, 2]

# %% [markdown]
# View tourney video

# %%
from IPython.display import Image
Image(VIDEO_FILE)

# %%
from pickle import load
fp = open(DATA_FILE, 'rb')
load(fp)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# /tmp/ipykernel_28384/1151690501.py in <module>
#       1 from pickle import load
#       2 fp = open(DATA_FILE, 'rb')
# ----> 3 load(fp)
#
# EOFError: Ran out of input
